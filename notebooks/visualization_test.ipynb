# %%
import sys
sys.path.append("../")
from experiments.visualizer import Visualizer

# %%
# pomps_paper_example_both_optimal0
# pomps_paper_graph0
# test
# cbo_aspirin_statin_hom

# %%
vs = Visualizer('../experiment_results/', 'test_aspirin_statin_hom_pomps', 5.075)

# %%
vs.policy_freq.groupby("index").freq.agg(sum).value_counts()
# Out:
# 1.0    40
# Name: freq, dtype: int64

# %%
vs.summary()
# Out:
# /opt/anaconda3/envs/SCMMABCOMBO/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/envs/SCMMABCOMBO/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
