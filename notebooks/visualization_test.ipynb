# %%
import sys
sys.path.append("../")
from experiments.visualizer import Visualizer, OptimizationObjective

# %%
# pomps_paper_example_both_optimal0
# pomps_paper_graph0
# test
# cbo_aspirin_statin_hom
# cbo_aspirin_statin_het
# contextual_pomps_paper_graph0
# pomps_aspirin_statin_het

# %%
vs = Visualizer('../experiment_results/', "cbo_aspirin_statin_het", OptimizationObjective.maximize, 1/3,)
vs1 = Visualizer('../experiment_results/', "pomps_aspirin_statin_het", OptimizationObjective.maximize, 1/3,  )

# %%
vs1.combined_df
# Out:
#      index         C        X1        X2         Y          MPS  EXP_ID  \
# 0        0 -0.219104 -1.000000  0.045651  0.007021  <X1, ['C']>       0
# 1        1 -0.486855  0.000000  0.463348  0.267248  <X1, ['C']>       0
# 2        2  0.881543  0.500000 -0.108782  0.088621  <X1, ['C']>       0
# 3        3  0.869196  0.999978  0.005687  0.009756  <X1, ['C']>       0
# 4        4 -0.176240 -0.176240 -2.000000  0.028792  <X2, ['C']>       0
# ..     ...       ...       ...       ...       ...          ...     ...
# 495    495  0.267585 -0.709439 -0.415494  0.212531  <X1, ['C']>       0
# 496    496 -0.986999  0.497799  0.470862  0.271788  <X1, ['C']>       0
# 497    497 -0.989759  0.630335 -0.701767  0.550492  <X1, ['C']>       0
# 498    498  0.550849 -0.556672  0.363204  0.137430  <X1, ['C']>       0
# 499    499  0.433798 -0.398051  0.244359  0.064126  <X1, ['C']>       0
#
#        Regret  Cum_Regret
# 0    0.326312    0.326312
# 1    0.066086    0.392398
# 2    0.244713    0.637111
# 3    0.323577    0.960688
# 4    0.304542    1.265230
# ..        ...         ...
# 495  0.120803   52.408208
# 496  0.061545   52.469753
# 497 -0.217159   52.252594
# 498  0.195903   52.448497
# 499  0.269208   52.717705
#
# [500 rows x 9 columns]

# %%
Visualizer.visualise_multiple([vs, vs1])

# %%
vs.policy_freq.groupby("index").freq.agg(sum).value_counts()
# Out:
# 1.0    700
# Name: freq, dtype: int64

# %%
df = vs.combined_df[vs.combined_df.EXP_ID == 0]

# %%
df.tail(100).Y.mean()
# Out:
# 0.5350088357925415

# %%
df.plot(kind='scatter', x='aspirin', y="statin", c='index')
# Out:
# <AxesSubplot:xlabel='aspirin', ylabel='statin'>

# %%
vs.summary()
