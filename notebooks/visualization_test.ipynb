# %%
import sys
sys.path.append("../")
from experiments.visualizer import Visualizer, OptimizationObjective

# %%
# pomps_paper_example_both_optimal0
# pomps_paper_graph0
# test
# cbo_aspirin_statin_hom
# cbo_aspirin_statin_het
# contextual_pomps_paper_graph0
# pomps_aspirin_statin_het

# %%
vs = Visualizer('../experiment_results/', "test_ad", 
                OptimizationObjective.maximize, 100_000, target="revenue", exp_dir='test_ad',
               uncertainty=('se', 1.96), central_tendency='mean')

# %%
vs.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 vs.summary()
#
# File ~\Desktop\POMPSBO\notebooks\..\experiments\visualizer.py:93, in Visualizer.summary(self)
#      91 for pl in self._plot():
#      92     plt.figure()
# ---> 93     pl()
#
# File ~\Desktop\POMPSBO\notebooks\..\experiments\visualizer.py:61, in Visualizer.plot_target(self, c)
#      60 def plot_target(self, c=None):
# ---> 61     return sns.lineplot(data=self.combined_df, x='index', y=self.target,
#      62                         estimator=self.central_tendency, errorbar=self.uncertainty,
#      63                         label=self.experiment_name).set(title="Target")
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\seaborn\relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\seaborn\relational.py:436, in _LinePlotter.plot(self, ax, kws)
#     425 """Draw the plot onto an axes, passing matplotlib kwargs."""
#     427 # Draw a test plot, using the passed in kwargs. The goal here is to
#     428 # honor both (a) the current state of the plot cycler and (b) the
#     429 # specified kwargs on all the lines we will draw, overriding when
#    (...)
#     433 # gotten from the corresponding matplotlib function, and calling the
#     434 # function will advance the axes property cycle.
# --> 436 scout, = ax.plot([], [], **kws)
#     438 orig_color = kws.pop("color", scout.get_color())
#     439 orig_marker = kws.pop("marker", scout.get_marker())
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_axes.py:1605, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1363 """
#    1364 Plot y versus x as lines and/or markers.
#    1365
#    (...)
#    1602 (``'green'``) or hex strings (``'#008000'``).
#    1603 """
#    1604 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
#    1607     self.add_line(line)
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_base.py:315, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     313     this += args[0],
#     314     args = args[1:]
# --> 315 yield from self._plot_args(this, kwargs)
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_base.py:539, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_base.py:539, in <listcomp>(.0)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\axes\_base.py:354, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     352 default_dict = self._getdefaults(set(), kw)
#     353 self._setdefaults(default_dict, kw)
# --> 354 seg = mlines.Line2D(x, y, **kw)
#     355 return seg, kw
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\lines.py:397, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     393 self.set_markeredgewidth(markeredgewidth)
#     395 # update kwargs before updating data to give the caller a
#     396 # chance to init axes (and hence unit support)
# --> 397 self.update(kwargs)
#     398 self.pickradius = pickradius
#     399 self.ind_offset = 0
#
# File D:\Conda\envs\POMPSBO\lib\site-packages\matplotlib\artist.py:1062, in Artist.update(self, props)
#    1060             func = getattr(self, f"set_{k}", None)
#    1061             if not callable(func):
# -> 1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
#    1064             ret.append(func(v))
#    1065 if ret:
#
# AttributeError: 'Line2D' object has no property 'errorbar'

# %%
vs.combined_df.revenue.rolling(20).mean().plot()
# Out:
# <AxesSubplot:>

# %%
vs.policy_freq.groupby("index").freq.agg(sum).value_counts()
# Out:
# 1.0    700
# Name: freq, dtype: int64

# %%
df = vs.combined_df[vs.combined_df.EXP_ID == 0]

# %%
df.tail(100).Y.mean()
# Out:
# 0.5350088357925415

# %%
df.plot(kind='scatter', x='aspirin', y="statin", c='index')
# Out:
# <AxesSubplot:xlabel='aspirin', ylabel='statin'>

# %%
vs.summary()
